# %% [markdown]
# # Matplotlib Visualization Overview

# %% [markdown]
# ## Overview

# %% [markdown]
# Matplotlib is one of most basic, simple and useful data visualization library available in python. It was created by John Hunter with a purpose to replicate MatLab's visualization abilities. If you are familier with MatLab, matplotlib will be very intutitve for you.

# %% [markdown]
# I would recommend to explore the offcial Matplotlib web page: http://matplotlib.org/

# %% [markdown]
# ## Installation

# %% [markdown]
# You will need to install matplotlib by typing following command in command prompt
# >conda install matplotlib

# %% [markdown]
# ## Importing

# %% [markdown]
# Import matplotlib.pyplot module under the name plt

# %%
import matplotlib.pyplot as plt
# %matplotlib inline 
#You will need to use this line to see plots in the notebook. 
#This line is only for jupyter notebook. 

#Also import Numpy as we will require it to generate data
import numpy as np

# %%
x = np.linspace(0,5,11)
y = x ** 2

#Show
print(x)
print(y)
# Out:
# [ 0.   0.5  1.   1.5  2.   2.5  3.   3.5  4.   4.5  5. ]
# [  0.     0.25   1.     2.25   4.     6.25   9.    12.25  16.    20.25  25.  ]

# %%
plt.plot(x,y,'r') #'r is the color red
plt.xlabel('X axis label here')
plt.ylabel('Y axis label here')
plt.title('String Title here')
plt.show()

# %% [markdown]
# ## Creating multiple plots on Same Canvas

# %%
# plt.subplot(nrows, ncols, plot_number)
plt.subplot(1,2,1)
plt.plot(x, y, 'r--') # More on color options later
plt.subplot(1,2,2)
plt.plot(y, x, 'g*-');

# %% [markdown]
# # Matplotlib Object Orientated Method

# %% [markdown]
# The main idea is using object orientated method is to create figure objects and then just call methods or attributes to plot figures.
#
# We first create a figure and then add axes to it.

# %%
#Create Figure(Empty)
fig = plt.figure()

#Add set of axes to figure
axes = fig.add_axes([1, 1, 1, 1])# left, bottom, width, height (range 0 to 1)

# Plot on that set of axes
axes.plot(x, y, 'b')
axes.set_xlabel('Set X Label') # Notice the use of set_ to begin methods
axes.set_ylabel('Set y Label')
axes.set_title('Set Title')

# %% [markdown]
# > Advantage of this method is we now have full control of where the plot axes are places and we can add more han one axis to the figure.

# %%
# Creates blank canvas
fig = plt.figure()

#Add axes 
axes1 = fig.add_axes([0.1, 0.1, 0.8, 0.8]) # main axes
axes2 = fig.add_axes([0.2, 0.5, 0.4, 0.3]) # inset axes

# Larger Figure Axes 1
axes1.plot(x, y, 'b')
axes1.set_xlabel('X_label_axes2')
axes1.set_ylabel('Y_label_axes2')
axes1.set_title('Axes 2 Title')

# Insert Figure Axes 2
axes2.plot(y, x, 'r')
axes2.set_xlabel('X_label_axes2')
axes2.set_ylabel('Y_label_axes2')
axes2.set_title('Axes 2 Title');

# %%
fig = plt.figure()

ax = fig.add_axes([1,1,1,1])

ax.plot(x, x**2, 'r.-', label = "x**2")
ax.plot(x, x**3, 'g--', label = "x**3")
ax.plot(x, x**4, label = "x**4")
ax.legend()

# %%
fig, ax = plt.subplots(figsize=(15,15))

ax.plot(x, x+1, color="red", linewidth=0.25)
ax.plot(x, x+2, color="red", linewidth=0.50)
ax.plot(x, x+3, color="red", linewidth=1.00)
ax.plot(x, x+4, color="red", linewidth=2.00)

# possible linestype options ‘-‘, ‘–’, ‘-.’, ‘:’, ‘steps’
ax.plot(x, x+5, color="green", lw=3, linestyle='-')
ax.plot(x, x+6, color="green", lw=3, ls='-.')
ax.plot(x, x+7, color="green", lw=3, ls=':')

# custom dash
line, = ax.plot(x, x+8, color="black", lw=1.50)
line.set_dashes([5, 10, 15, 10]) # format: line length, space length, ...

# possible marker symbols: marker = '+', 'o', '*', 's', ',', '.', '1', '2', '3', '4', ...
ax.plot(x, x+ 9, color="blue", lw=3, ls='-', marker='+')
ax.plot(x, x+10, color="blue", lw=3, ls='--', marker='o')
ax.plot(x, x+11, color="blue", lw=3, ls='-', marker='s')
ax.plot(x, x+12, color="blue", lw=3, ls='--', marker='1')

# marker size and color
ax.plot(x, x+13, color="purple", lw=1, ls='-', marker='o', markersize=2)
ax.plot(x, x+14, color="purple", lw=1, ls='-', marker='o', markersize=4)
ax.plot(x, x+15, color="purple", lw=1, ls='-', marker='o', markersize=8, markerfacecolor="red")
ax.plot(x, x+16, color="purple", lw=1, ls='-', marker='s', markersize=8, markerfacecolor="yellow", markeredgewidth=3, markeredgecolor="green");

# %%
#Create igures with axes
fig, axes = plt.subplots(2, 3, figsize=(12,4))

#add data on axes[0][0]
axes[0][0].plot(x, x**2, x, x**3)

#add data on axes[1][2]
axes[1][2].plot(x,x**2, x, x**4)

# %%
#import math library

import math 

x = np.linspace(1,10,20)
y = np.log(x)

#Show
print(x)
print(y)
# Out:
# [  1.           1.47368421   1.94736842   2.42105263   2.89473684
#    3.36842105   3.84210526   4.31578947   4.78947368   5.26315789
#    5.73684211   6.21052632   6.68421053   7.15789474   7.63157895
#    8.10526316   8.57894737   9.05263158   9.52631579  10.        ]
# [ 0.          0.38776553  0.66647893  0.88420242  1.06289421  1.2144441
#   1.34602046  1.46228027  1.56642053  1.66073121  1.7469089   1.82624565
#   1.89974811  1.96821591  2.03229476  2.09251362  2.14931122  2.2030555
#   2.25405805  2.30258509]

# %%
plt.scatter(x,y)

# %%
from random import sample
data = sample(range(1,1000), 100)
plt.hist(data)
# Out:
# (array([ 10.,   6.,  11.,  10.,  12.,   8.,  15.,  15.,   4.,   9.]),
#  array([  12. ,  109.9,  207.8,  305.7,  403.6,  501.5,  599.4,  697.3,
#          795.2,  893.1,  991. ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# >random.sample  picks a subset of the input sequence, randomly, without picking any one element more than once. If your input sequence has no repetitions, neither will your output.
#
# > data = sample(range(1,100),1000) will give us error

# %%
fig, axes = plt.subplots(1, 4, figsize=(12,3))

axes[0].scatter(xx, xx + 0.25*np.random.randn(len(xx)))
axes[0].set_title("scatter")



axes[3].fill_between(x, x**2, x**3, color="green", alpha=0.5);
axes[3].set_title("fill_between");
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-29a7e3b8904e> in <module>()
#       1 fig, axes = plt.subplots(1, 4, figsize=(12,3))
#       2
# ----> 3 axes[0].scatter(xx, xx + 0.25*np.random.randn(len(xx)))
#       4 axes[0].set_title("scatter")
#       5
#
# NameError: name 'xx' is not defined

# %%
fig, axes = plt.subplots(1,2,figsize = (15,8))

n = np.array([1,2,3,4,5,6,7,8,10,13])

axes[0].step(n, n**2, lw=2)
axes[0].set_title("step")

axes[1].bar(n, n**2, align="center", width=0.5, alpha=0.5)
axes[1].set_title("bar")

# %%
x = np.linspace(-1, 2, 100)

fig, axes = plt.subplots(1,2, figsize=(15,8))

axes[0].scatter(x,x + 0.25 * np.random.randn((len(x))))
axes[0].set_title("scatter")

axes[1].fill_between(x,x**2, color= "green", alpha = 0.5)
axes[1].set_title("fill_between")
