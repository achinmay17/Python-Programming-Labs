# %% [markdown]
# ## Pandas Built-in visualizations

# %% [markdown]
# Pandas built-in visualization tools are very handy in a way that you don't have to import any external libararies and they also cover most of the baisc plots which are required for day-to-day data analysis.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df1 = pd.read_csv('df1.csv', index_col = 0)
df2 = pd.read_csv('df2.csv')

# %%
df1.head()
# Out:
#                    A         B         C        D
# 01-01-2000  2.339091  0.836357  0.353557  2.041233
# 02-01-2000  0.225016  1.137034  0.117284 -1.253382
# 03-01-2000  0.078963  0.517057  0.582900  1.478638
# 04-01-2000 -0.738808  0.927027  1.056517  1.015085
# 05-01-2000  0.094020  2.778576  1.381918  1.291436

# %%
df1['A'].hist()

# %% [markdown]
# ### Style sheets

# %% [markdown]
# Matplotlib has 'style sheets' which you can use to make your plots look a little nicer. I have used one style below. I recommend try using different styles and see the difference!

# %%
plt.style.use('ggplot')

# %%
df1['A'].hist()

# %% [markdown]
# >try using 'bmh', 'dark_background', 'fivethirtyeight' and see the differece between different plots

# %% [markdown]
# ## Plot Types

# %% [markdown]
# There are several plot types which are built-in to pandas.
# * df.plot.area
# * df.plot.barh
# * df.plot.density
# * df.plot.hist
# * df.plot.line
# * df.plot.scatter
# * df.plot.bar
# * df.plot.box
# * df.plot.hexbin
# * df.plot.kde
# * df.plot.pie

# %% [markdown]
# There are 2 ways by which you can specify the plot:
# >1) df.plot.area
#
# or you can say
#
# >2) df.plot(kind='area')
#
# you can replace kind argument with any of the key plot types shown in the list above

# %% [markdown]
# ### Area

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  1.039762  1.218517  1.103423  1.957904
# 1  1.937288  1.041567  1.899125  1.977680
# 2  1.780504  1.008948  1.557808  1.797510
# 3  1.672717  1.247870  1.264071  1.444358
# 4  1.053829  1.520124  1.552264  1.190008

# %%
df2.plot.area(alpha = 0.5)
#you can change alpah for transparancy of area plot

# %% [markdown]
# ### Bar

# %%
df2.plot(kind ='bar')

# %%
df2.plot(kind ='bar',stacked = True)

# %% [markdown]
# ### Histogram

# %%
df1['A'].plot.hist(bins = 50)

# %%
df1['A'].plot.hist(bins = 10)

# %% [markdown]
# ### Line Plots

# %%
df1.plot.line(x=df1.index, y='B', figsize = (12,6), lw=1)

# %%
df1.plot.line(x=df1.index, y='B', figsize = (12,6), lw=1)

# %% [markdown]
# ### Scatter plots

# %%
df1.plot.scatter(x='A' , y='B')

# %%
df1.plot.scatter(x='A',y='B',c='C', cmap = 'coolwarm')
# s stands for size. s needs to be an array denoting sizes for different columns
# cmap

# %%
df1.plot.scatter(x='A', y ='B', s=df1['C']*100)
# Out:
# C:\Users\ajnad\Anaconda3\lib\site-packages\matplotlib\collections.py:877: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %% [markdown]
# ### Box Plots

# %%
df2.plot.box()
#we can alos pass by= argument for groupby

# %% [markdown]
# ### Hexagonal Bin Plot

# %% [markdown]
# hexagonal plots are useful for Bivariate data, alternative to scatterplot

# %%
df = pd.DataFrame(np.random.randn(1000,2), columns=['a', 'b'])
df.plot.hexbin(x='a', y='b', gridsize= 30, cmap = 'Oranges')

# %% [markdown]
# ### Kernel Density Estimation Plot (KDE)

# %%
df2['a'].plot.kde()

# %%
df2.plot.density()
